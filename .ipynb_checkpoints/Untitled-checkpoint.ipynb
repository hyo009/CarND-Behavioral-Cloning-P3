# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn

import os
import csv
import sklearn
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Lambda, Flatten, Dense, Convolution2D
from keras.models import load_model
from keras import callbacks
from keras.optimizers import Adam
# %matplotlib inline

# %%
# load data
dataLocation = './data/'
samples = []
with open(dataLocation + 'driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        samples.append(line)

# %%
# split training and test data
train_samples, test_samples = train_test_split(samples[1:], test_size = 0.2)

print('training examples:', len(train_samples))
print('test examples:', len(test_samples))
# Out:
# training examples: 6428
# test examples: 1608

# %%
correction = 0.2 # this is a parameter to tune

# %%
# visualize one sample
m = np.random.randint(0,len(samples))
print('training example m :', m)

sample = samples[m]
print(sample[0])
center_img = cv2.imread(dataLocation + sample[0])
left_img = cv2.imread(dataLocation + sample[1])
right_img = cv2.imread(dataLocation + sample[2])

center_angle = float(sample[3])
left_angle = center_angle + correction
right_angle = center_angle - correction
print('center_angle' , center_angle)

plt.figure
plt.imshow(center_img)

print(center_img.shape)
# Out:
# training example m : 4624
# IMG/center_2016_12_01_13_40_55_720.jpg
# center_angle 0.1765823
# (160, 320, 3)

# %%
# Crop top and bottom images to remove sky and front of the car (NVIDIA's paper)
def preprocessing(image):
    # crop to 90x320x3
    image = image[50:140,:,:]
    
    # scale to 66x200x3 (same as NVIDIA)
    image = cv2.resize(image,(200, 66), interpolation = cv2.INTER_AREA)

    # convert to YUV color space (same as NVIDIA)
    return cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    
    # return image

# %%
center_img = preprocessing(center_img)

plt.figure
plt.imshow(center_img)

print(center_img.shape)
# Out:
# (66, 200, 3)

# %%
# generators
def generator_training(samples, batch_size=128):
    while 1: # Loop forever so the generator never terminates
        sklearn.utils.shuffle(samples)
        for offset in range(0, len(samples), batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images = []
            angles = []
            for batch_sample in batch_samples:
                center_image = cv2.imread(dataLocation + batch_sample[0])
                # left_image = cv2.imread(dataLocation + batch_sample[1])
                # right_image = cv2.imread(dataLocation + batch_sample[2])
                
                center_angle = float(batch_sample[3])
                # left_angle = center_angle + correction
                # right_angle = center_angle - correction
                
                # Randomly flips the images to help create even amount of left turns and right turns
                if np.random.rand() > .5:
                    center_image = cv2.flip(center_image, 1)
                    center_angle *= -1
                
                # Preprocess data            
                images.append(preprocessing(center_image))
  
                angles.append(center_angle)

            X_train = np.array(images)
            y_train = np.array(angles)
            yield sklearn.utils.shuffle(X_train, y_train)

# %%
def generator_test(samples, batch_size=128):
    while 1: # Loop forever so the generator never terminates
        sklearn.utils.shuffle(samples)
        for offset in range(0, len(samples), batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images = []
            angles = []
            for batch_sample in batch_samples:
                center_image = cv2.imread(dataLocation + batch_sample[0])
                
                center_angle = float(batch_sample[3])
                
                images.append(preprocessing(center_image))
                
                angles.append(center_angle)

            X_train = np.array(images)
            y_train = np.array(angles)
            yield sklearn.utils.shuffle(X_train, y_train)

# %%
# compile and train the model using the generator function
train_generator = generator_training(train_samples, batch_size = 256)
validation_generator = generator_test(test_samples, batch_size = 256)

# %%
def nvidia_model():   
    model = Sequential()
    
    model.add(Lambda(lambda x: x/127.5 - 1, input_shape = (66,200,3)))
    
    model.add(Convolution2D(24, 5, 5, subsample = (2, 2), border_mode = "valid", activation = 'elu'))
    model.add(Convolution2D(36, 5, 5, subsample = (2, 2), border_mode = "valid", activation = 'elu'))
    model.add(Convolution2D(48, 5, 5, subsample = (2, 2), border_mode = "valid", activation = 'elu'))
    model.add(Convolution2D(64, 3, 3, subsample = (1, 1), border_mode = "valid", activation = 'elu'))
    model.add(Convolution2D(64, 3, 3, subsample = (1, 1), border_mode = "valid", activation = 'elu'))
    
    model.add(Flatten())
    
    model.add(Dense(100, activation = 'elu'))
    model.add(Dense(50, activation = 'elu'))
    model.add(Dense(10, activation = 'elu'))
    model.add(Dense(1, activation = 'elu'))
    
    model.summary()
    
    return model

# %%
# For creating a new model
model = nvidia_model()

# Load the pretrained model to train on another data set
# model = load_model('model.h5')
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_7 (Lambda)                (None, 66, 200, 3)    0           lambda_input_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D) (None, 31, 98, 24)    1824        lambda_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D) (None, 14, 47, 36)    21636       convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D) (None, 5, 22, 48)     43248       convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D) (None, 3, 20, 64)     27712       convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D) (None, 1, 18, 64)     36928       convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# flatten_7 (Flatten)              (None, 1152)          0           convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# dense_25 (Dense)                 (None, 100)           115300      flatten_7[0][0]
# ____________________________________________________________________________________________________
# dense_26 (Dense)                 (None, 50)            5050        dense_25[0][0]
# ____________________________________________________________________________________________________
# dense_27 (Dense)                 (None, 10)            510         dense_26[0][0]
# ____________________________________________________________________________________________________
# dense_28 (Dense)                 (None, 1)             11          dense_27[0][0]
# ====================================================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
# train the model
model_path = os.path.expanduser('model.h5')
save_best = callbacks.ModelCheckpoint(model_path, 
                                      monitor = 'val_loss', 
                                      verbose = 1, 
                                      save_best_only = True, 
                                      mode = 'min')
early_stop = callbacks.EarlyStopping(monitor = 'val_loss', 
                                     min_delta = 0.001, 
                                     patience = 3, 
                                     verbose = 0, 
                                     mode = 'auto')
callbacks_list = [early_stop, save_best]

model.compile(loss = 'mse', optimizer = 'adam')
history_object = model.fit_generator(train_generator, 
                                     samples_per_epoch = len(train_samples),
                                     validation_data = validation_generator,
                                     nb_val_samples = len(test_samples),
                                     nb_epoch = 3,
                                     callbacks = callbacks_list)
# Out:
# Epoch 1/3
# 6400/6428 [============================>.] - ETA: 0s - loss: 0.0549Epoch 00000: val_loss improved from inf to 0.01445, saving model to model.h5
# 6428/6428 [==============================] - 116s - loss: 0.0547 - val_loss: 0.0145
# Epoch 2/3
# 6400/6428 [============================>.] - ETA: 0s - loss: 0.0135Epoch 00001: val_loss improved from 0.01445 to 0.01180, saving model to model.h5
# 6428/6428 [==============================] - 103s - loss: 0.0134 - val_loss: 0.0118
# Epoch 3/3
# 6400/6428 [============================>.] - ETA: 0s - loss: 0.0116Epoch 00002: val_loss improved from 0.01180 to 0.01065, saving model to model.h5
# 6428/6428 [==============================] - 101s - loss: 0.0116 - val_loss: 0.0107

# %%
# plot the training and validation loss for each epoch
plt.figure
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
